# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## import pizza sales data

# %%
pizza_sales_df = pd.read_excel('pizza_sales.xlsx')
pizza_sales_df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %% [markdown]
# ## import pizza size data

# %%
pizza_size_df = pd.read_csv('pizza_size.csv')
pizza_size_df
# Out:
#    pizza_size_id size
# 0              1    S
# 1              2    M
# 2              3    L
# 3              4   XL
# 4              5  XXL

# %% [markdown]
# ## import pizza sales voucher data

# %%
pizza_sales_voucher_df = pd.read_excel('pizza_sales_voucher.xlsx')
pizza_sales_voucher_df
# Out:
#        order_details_id  voucher_number
# 0                     1         1474326
# 1                     2         1300889
# 2                     3         1902352
# 3                     4         1215184
# 4                     5         1737749
# ...                 ...             ...
# 48615             48616         1778172
# 48616             48617         1071115
# 48617             48618         1107321
# 48618             48619         1934033
# 48619             48620         1758324
#
# [48620 rows x 2 columns]

# %% [markdown]
# ## import pizza categories data

# %%
pizza_category_df = pd.read_csv('pizza_category.csv')
pizza_category_df
# Out:
#    pizza_category_id category
# 0                  1  Chicken
# 1                  2  Classic
# 2                  3  Supreme
# 3                  4   Veggie

# %% [markdown]
# ## Describe sales Data

# %%
pizza_sales_df.describe()
# Out:
#        order_details_id      order_id      quantity    order_time  \
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761      1.019622      0.683927
# std        14035.529381   6180.119770      0.143077      0.130513
# min            1.000000      1.000000      1.000000      0.411354
# 25%        12155.750000   5337.000000      1.000000      0.558866
# 50%        24310.500000  10682.500000      1.000000      0.689965
# 75%        36465.250000  16100.000000      1.000000      0.788414
# max        48620.000000  21350.000000      4.000000      0.962407
#
#          unit_price   total_price  pizza_size_id  pizza_category_id
# count  48620.000000  48620.000000   48620.000000       48620.000000
# mean      16.494132     16.821474       2.114377           2.490745
# std        3.621789      4.437398       0.841827           1.079711
# min        9.750000      9.750000       1.000000           1.000000
# ...

# %% [markdown]
# ## Describe Size Data

# %%
pizza_size_df.describe()
# Out:
#        pizza_size_id
# count       5.000000
# mean        3.000000
# std         1.581139
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %% [markdown]
# ## Describe sales voucher Data

# %%
pizza_sales_voucher_df.describe()
# Out:
#        order_details_id  voucher_number
# count      48620.000000    4.862000e+04
# mean       24310.500000    1.500199e+06
# std        14035.529381    2.880410e+05
# min            1.000000    1.000011e+06
# 25%        12155.750000    1.252830e+06
# 50%        24310.500000    1.499416e+06
# 75%        36465.250000    1.748737e+06
# max        48620.000000    1.999999e+06

# %% [markdown]
# ## show the info about sales data

# %%
pizza_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48618 non-null  datetime64[ns]
#  5   order_time         48620 non-null  float64
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size_id      48620 non-null  int64
#  9   pizza_category_id  48620 non-null  int64
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# ## check null values in sales data and solve it

# %%
pizza_sales_df.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           2
# order_time           0
# unit_price           0
# total_price          0
# pizza_size_id        0
# pizza_category_id    0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
most_repated_date = pizza_sales_df['order_date'].mode()[0]
most_repated_date = str(most_repated_date)
most_repated_date
# Out:
# '2015-11-26 00:00:00'

# %%
pizza_sales_df[pizza_sales_df['order_date'].isnull() == True]
# Out:
#       order_details_id  order_id       pizza_id  quantity order_date  \
# 5901              5902      2614  the_greek_xxl         1        NaT
# 6335              6336      2801    pepperoni_s         1        NaT
#
#       order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# 5901    0.578079       35.95        35.95              5                  2
# 6335    0.665347        9.75         9.75              1                  2
#
#                                       pizza_ingredients           pizza_name
# 5901  Kalamata Olives, Feta Cheese, Tomatoes, Garlic...      The Greek Pizza
# 6335                       Mozzarella Cheese, Pepperoni  The Pepperoni Pizza

# %%
pizza_sales_df = pizza_sales_df.fillna(most_repated_date)

# %%
pizza_sales_df.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size_id        0
# pizza_category_id    0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %% [markdown]
# ## show the info about sales voucher data

# %%
pizza_sales_voucher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   voucher_number    48620 non-null  int64
# dtypes: int64(2)
# memory usage: 759.8 KB

# %% [markdown]
# ## check null values in sales data and solve it

# %%
pizza_sales_voucher_df.isnull().sum()
# Out:
# order_details_id    0
# voucher_number      0
# dtype: int64

# %% [markdown]
# ## check for duplicate data

# %%
pizza_sales_df.duplicated().sum()
# Out:
# 0

# %%
pizza_sales_voucher_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ### Quantity Saled Graph

# %%
plt.figure(figsize=(18, 10))
pizza_sales_df["quantity"].hist(bins=8)
plt.title('Total quantity Frequency')
plt.ylabel('Total quantity')
plt.xlabel('quantity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### we found that most sales happened for orders 1 pizza at a time

# %% [markdown]
# ## merging all tables for further analysis

# %%
merged_data = pd.merge(pizza_sales_df,pizza_category_df, on = 'pizza_category_id')
merged_data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                    12         6    the_greek_s         1 2015-01-01
# 3                    15         9  classic_dlx_s         1 2015-01-01
# 4                    17         9  ital_cpcllo_l         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48610     21346     cali_ckn_s         1 2015-12-31
# 48616             48612     21347      bbq_ckn_m         1 2015-12-31
# 48617             48615     21347   southw_ckn_l         1 2015-12-31
# 48618             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
merged_data = pd.merge(merged_data,pizza_size_df, on = 'pizza_size_id')
merged_data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                    60        22  ital_cpcllo_m         1 2015-01-01
# 3                    64        24  ital_cpcllo_m         1 2015-01-01
# 4                    65        24    pepperoni_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             39733     17492  the_greek_xxl         1 2015-10-24
# 48616             41183     18139  the_greek_xxl         1 2015-11-05
# 48617             42718     18789  the_greek_xxl         1 2015-11-17
# 48618             43041     18919  the_greek_xxl         1 2015-11-19
# 48619             47490     20866  the_greek_xxl         1 2015-12-20
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
merged_data = pd.merge(merged_data,pizza_sales_voucher_df, on = 'order_details_id')
merged_data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                    60        22  ital_cpcllo_m         1 2015-01-01
# 3                    64        24  ital_cpcllo_m         1 2015-01-01
# 4                    65        24    pepperoni_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             39733     17492  the_greek_xxl         1 2015-10-24
# 48616             41183     18139  the_greek_xxl         1 2015-11-05
# 48617             42718     18789  the_greek_xxl         1 2015-11-17
# 48618             43041     18919  the_greek_xxl         1 2015-11-19
# 48619             47490     20866  the_greek_xxl         1 2015-12-20
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %% [markdown]
# ### Now we had one dataframe has all data called 'merged_data' and the column names are as the following:

# %%
merged_data.columns
# Out:
# Index(['order_details_id', 'order_id', 'pizza_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size_id',
#        'pizza_category_id', 'pizza_ingredients', 'pizza_name', 'category',
#        'size', 'voucher_number'],
#       dtype='object')

# %% [markdown]
# ### filtering data according to each category sales

# %%
category_total = merged_data.groupby('category', as_index = False)['total_price'].sum()
category_total
# Out:
#   category  total_price
# 0  Chicken    195919.50
# 1  Classic    220053.10
# 2  Supreme    208197.00
# 3   Veggie    193690.45

# %%
category_total_desc = category_total.sort_values('total_price', ascending = False)
category_total_desc
# Out:
#   category  total_price
# 1  Classic    220053.10
# 2  Supreme    208197.00
# 0  Chicken    195919.50
# 3   Veggie    193690.45

# %% [markdown]
# ## most sales occures for 'classic' pizza type and the least is for 'Veggie'

# %% [markdown]
# ## To Know the percent of each sales for every category of the 4. visualize it as pie graph

# %%
plt.figure(figsize=(14,14))
plt.pie(category_total['total_price'], labels=category_total['category'], autopct='%1.1f%%', startangle=45, colors=sns.color_palette('pastel'))
plt.title('Sales Distribution by Category')
plt.show()

# %% [markdown]
# ### we found that the percents of sales are nearly equal

# %% [markdown]
# ## visualize the price frequency at each point of sale

# %%
plt.figure(figsize=(18, 10))
merged_data["unit_price"].hist(bins=20)
plt.title('Total price Frequency')
plt.ylabel('Total price')
plt.xlabel('price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### we found that the most sales occurs at value more than 20 and less than 22.5

# %%
merged_data[merged_data['unit_price'] > 20]
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 24018               428       182   brie_carre_s         1 2015-01-03
# 24029               578       253   brie_carre_s         1 2015-01-04
# 24030               580       254   brie_carre_s         1 2015-01-04
# 24031               593       261   brie_carre_s         1 2015-01-05
# 24036               654       288   brie_carre_s         1 2015-01-05
# ...                 ...       ...            ...       ...        ...
# 48615             39733     17492  the_greek_xxl         1 2015-10-24
# 48616             41183     18139  the_greek_xxl         1 2015-11-05
# 48617             42718     18789  the_greek_xxl         1 2015-11-17
# 48618             43041     18919  the_greek_xxl         1 2015-11-19
# 48619             47490     20866  the_greek_xxl         1 2015-12-20
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
size_more_than_20 = merged_data.groupby(['size'], as_index = False)['total_price'].sum()
size_more_than_20
# Out:
#   size  total_price
# 0    L    375318.70
# 1    M    249382.25
# 2    S    178076.50
# 3   XL     14076.00
# 4  XXL      1006.60

# %% [markdown]
# ### we filltered them according to total price for each size

# %%
plt.figure(figsize=(14,14))
plt.pie(size_more_than_20['total_price'], labels=size_more_than_20['size'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Sales Distribution by size')
plt.show()

# %% [markdown]
# ### we found that the most revenues is for Large sized pizza over 20 and least for XXL size

# %%
quantity_Data_more_than_1 = merged_data[merged_data['quantity']>1]
quantity_Data_more_than_1
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 21                  223        92    the_greek_m         2 2015-01-02
# 68                  803       350    pepperoni_m         2 2015-01-06
# 76                  903       394    pepperoni_m         3 2015-01-07
# 101                1190       522  ital_cpcllo_m         2 2015-01-09
# 226                2877      1271  classic_dlx_m         2 2015-01-22
# ...                 ...       ...            ...       ...        ...
# 48335             24184     10624   the_greek_xl         2 2015-06-27
# 48487             38829     17112   the_greek_xl         2 2015-10-17
# 48501             39724     17488   the_greek_xl         2 2015-10-24
# 48559             45520     19988   the_greek_xl         2 2015-12-06
# 48571             46789     20543   the_greek_xl         2 2015-12-15
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
plt.figure(figsize=(18, 10))
quantity_Data_more_than_1["quantity"].hist(bins=6)
plt.title('Total quantity Frequency')
plt.ylabel('Total quantity')
plt.xlabel('quantity')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %% [markdown]
# ### we found that the sales for quantity = 2 is the most and least is quantity = 4

# %%
Highest_repeated_quantity = quantity_Data_more_than_1[quantity_Data_more_than_1['quantity']==4]
Highest_repeated_quantity
# Out:
#        order_details_id  order_id    pizza_id  quantity order_date  \
# 16852             11977      5264  big_meat_s         4 2015-03-30
# 17717             18876      8286  big_meat_s         4 2015-05-19
# 46712             35497     15674  cali_ckn_l         4 2015-09-19
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# 16852    0.558738       12.00         48.0              1                  2
# 17717    0.529699       12.00         48.0              1                  2
# 46712    0.594850       20.75         83.0              3                  1
#
#                                        pizza_ingredients  \
# 16852  Bacon, Pepperoni, Italian Sausage, Chorizo Sau...
# 17717  Bacon, Pepperoni, Italian Sausage, Chorizo Sau...
# 46712  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
#
#                          pizza_name category size  voucher_number
# 16852            The Big Meat Pizza  Classic    S         1103663
# ...

# %%
most_repeated_quantity.count()
# Out:
# order_details_id     3
# order_id             3
# pizza_id             3
# quantity             3
# order_date           3
# order_time           3
# unit_price           3
# total_price          3
# pizza_size_id        3
# pizza_category_id    3
# pizza_ingredients    3
# pizza_name           3
# category             3
# size                 3
# voucher_number       3
# dtype: int64

# %% [markdown]
# ### we found that the orders of quantity = 4 are 3 orders only.

# %%
merged_data['Month_Year'] = merged_data['order_date'].dt.to_period('M')
merged_data['Month_Year']
# Out:
# 0        2015-01
# 1        2015-01
# 2        2015-01
# 3        2015-01
# 4        2015-01
#           ...
# 48615    2015-10
# 48616    2015-11
# 48617    2015-11
# 48618    2015-11
# 48619    2015-12
# Name: Month_Year, Length: 48620, dtype: period[M]

# %%
month_Price_Data = merged_data.groupby('Month_Year')['total_price'].sum()
month_Price_Data
# Out:
# Month_Year
# 2015-01    69793.30
# 2015-02    65113.90
# 2015-03    70397.10
# 2015-04    68736.80
# 2015-05    71402.75
# 2015-06    68230.20
# 2015-07    72557.90
# 2015-08    68278.25
# 2015-09    64180.05
# 2015-10    64027.60
# 2015-11    70441.05
# 2015-12    64701.15
# Freq: M, Name: total_price, dtype: float64

# %%
month_Price_Data = month_Price_Data.reset_index()
month_Price_Data
# Out:
#    Month_Year  total_price
# 0     2015-01     69793.30
# 1     2015-02     65113.90
# 2     2015-03     70397.10
# 3     2015-04     68736.80
# 4     2015-05     71402.75
# 5     2015-06     68230.20
# 6     2015-07     72557.90
# 7     2015-08     68278.25
# 8     2015-09     64180.05
# 9     2015-10     64027.60
# 10    2015-11     70441.05
# 11    2015-12     64701.15

# %%
month_Price_Data['Month_Year'] = month_Price_Data['Month_Year'].astype(str)

# %%
plt.figure(figsize=(18, 10))
plt.plot(month_Price_Data['Month_Year'],month_Price_Data['total_price'], color='red', marker = 'x')
plt.ticklabel_format(useOffset=False, style='plain', axis='y')
plt.title('total Revenue value by month and year')
plt.ylabel('Total Amount',fontsize=14)
plt.xlabel('Month and Year', fontsize=14)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# ### we found that the high values for total price is in 2015-7 we will analyze it alone

# %%
merged_data['Week_Year'] = merged_data['order_date'].dt.to_period('W')
merged_data['Week_Year']
# Out:
# 0        2014-12-29/2015-01-04
# 1        2014-12-29/2015-01-04
# 2        2014-12-29/2015-01-04
# 3        2014-12-29/2015-01-04
# 4        2014-12-29/2015-01-04
#                  ...
# 48615    2015-10-19/2015-10-25
# 48616    2015-11-02/2015-11-08
# 48617    2015-11-16/2015-11-22
# 48618    2015-11-16/2015-11-22
# 48619    2015-12-14/2015-12-20
# Name: Week_Year, Length: 48620, dtype: period[W-SUN]

# %%
June_Sales_Data = merged_data[merged_data['Month_Year']== '2015-07']
June_Sales_Data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 2007              24567     10796     hawaiian_m         1 2015-07-01
# 2008              24579     10803  classic_dlx_m         1 2015-07-01
# 2009              24582     10805    pepperoni_m         1 2015-07-01
# 2010              24602     10813    the_greek_m         1 2015-07-01
# 2011              24624     10824  ital_cpcllo_m         1 2015-07-01
# ...                 ...       ...            ...       ...        ...
# 48386             28516     12558   the_greek_xl         1 2015-07-29
# 48387             28544     12570   the_greek_xl         1 2015-07-29
# 48388             28654     12616   the_greek_xl         1 2015-07-30
# 48389             28744     12665   the_greek_xl         1 2015-07-31
# 48390             28826     12711   the_greek_xl         1 2015-07-31
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
June_Sales_Data.count()
# Out:
# order_details_id     4301
# order_id             4301
# pizza_id             4301
# quantity             4301
# order_date           4301
# order_time           4301
# unit_price           4301
# total_price          4301
# pizza_size_id        4301
# pizza_category_id    4301
# pizza_ingredients    4301
# pizza_name           4301
# category             4301
# size                 4301
# voucher_number       4301
# Month_Year           4301
# Week_Year            4301
# dtype: int64

# %%
week_Price_Data = June_Sales_Data.groupby('Week_Year')['total_price'].sum()
week_Price_Data
# Out:
# Week_Year
# 2015-06-29/2015-07-05    13424.95
# 2015-07-06/2015-07-12    15888.70
# 2015-07-13/2015-07-19    16258.25
# 2015-07-20/2015-07-26    16351.65
# 2015-07-27/2015-08-02    10634.35
# Freq: W-SUN, Name: total_price, dtype: float64

# %%
week_Price_Data = week_Price_Data.reset_index()
week_Price_Data
# Out:
#                Week_Year  total_price
# 0  2015-06-29/2015-07-05     13424.95
# 1  2015-07-06/2015-07-12     15888.70
# 2  2015-07-13/2015-07-19     16258.25
# 3  2015-07-20/2015-07-26     16351.65
# 4  2015-07-27/2015-08-02     10634.35

# %%
week_Price_Data['Week_Year'] = week_Price_Data['Week_Year'].astype(str)

# %%
plt.figure(figsize=(18, 10))
plt.plot(week_Price_Data['Week_Year'],week_Price_Data['total_price'], color='red', marker = 'x')
plt.ticklabel_format(useOffset=False, style='plain', axis='y')
plt.title('total Revenue value by month and year')
plt.ylabel('Total Amount',fontsize=14)
plt.xlabel('Month and Year', fontsize=14)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# ### we found that the curve is started at 12-7-2015 till 26-7-2015 around 2 weeks

# %%
June_Sales_Data_Categories = June_Sales_Data.groupby(['category'], as_index = False)['total_price'].sum()
June_Sales_Data_Categories
# Out:
#   category  total_price
# 0  Chicken     17002.25
# 1  Classic     19653.00
# 2  Supreme     18216.85
# 3   Veggie     17685.80

# %%
June_Sales_Data_Categories_DESC = June_Sales_Data_Categories.sort_values('total_price', ascending = False)
June_Sales_Data_Categories_DESC
# Out:
#   category  total_price
# 1  Classic     19653.00
# 2  Supreme     18216.85
# 3   Veggie     17685.80
# 0  Chicken     17002.25

# %%
plt.figure(figsize=(14,14))
plt.pie(June_Sales_Data_Categories['total_price'], labels=June_Sales_Data_Categories['category'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Sales Distribution by size')
plt.show()

# %% [markdown]
# #### we found that the classic is most sold item and chicken is the least

# %%
merged_data.describe()
# Out:
#        order_details_id      order_id      quantity    order_time  \
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761      1.019622      0.683927
# std        14035.529381   6180.119770      0.143077      0.130513
# min            1.000000      1.000000      1.000000      0.411354
# 25%        12155.750000   5337.000000      1.000000      0.558866
# 50%        24310.500000  10682.500000      1.000000      0.689965
# 75%        36465.250000  16100.000000      1.000000      0.788414
# max        48620.000000  21350.000000      4.000000      0.962407
#
#          unit_price   total_price  pizza_size_id  pizza_category_id  \
# count  48620.000000  48620.000000   48620.000000       48620.000000
# mean      16.494132     16.821474       2.114377           2.490745
# std        3.621789      4.437398       0.841827           1.079711
# min        9.750000      9.750000       1.000000           1.000000
# ...

# %%
plt.figure(figsize=(18, 10))
sns.boxplot(x='category', y='order_time', data=merged_data, palette='Set2')
plt.title('Distribution of order time by category type')
plt.ylabel('order time')
plt.xlabel('category type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### nearly equal time

# %%
plt.figure(figsize=(18, 10))
sns.boxplot(x='size', y='order_time', data=merged_data, palette='Set2')
plt.title('Distribution of order time by category type')
plt.ylabel('order time')
plt.xlabel('size type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### XXL time range is less time than others

# %% [markdown]
# ## we filltering out the high price pizza

# %%
High_Price_Items = merged_data[merged_data['unit_price']>=35]
High_Price_Items
# Out:
#        order_details_id  order_id               pizza_id  quantity order_date  \
# 48592              3448      1528          the_greek_xxl         1 2015-01-26
# 48593              3564      1581          the_greek_xxl         1 2015-01-27
# 48594              5902      2614          the_greek_xxl         1 2015-11-26
# 48595              6366      2813          the_greek_xxl         1 2015-02-16
# 48596              7491      3297          the_greek_xxl         1 2015-02-25
# 48597              9845      4307          the_greek_xxl         1 2015-03-14
# 48598             10283      4498          the_greek_xxl         1 2015-03-17
# 48599             10876      4761          the_greek_xxl         1 2015-03-21
# 48600             13512      5927          the_greek_xxl         1 2015-04-10
# 48601             13780      6038          the_greek_xxl         1 2015-04-12
# 48602             14030      6150          the_greek_xxl         1 2015-04-13
# ...

# %%
High_Price_Items.count()
# Out:
# order_details_id     28
# order_id             28
# pizza_id             28
# quantity             28
# order_date           28
# order_time           28
# unit_price           28
# total_price          28
# pizza_size_id        28
# pizza_category_id    28
# pizza_ingredients    28
# pizza_name           28
# category             28
# size                 28
# voucher_number       28
# Month_Year           28
# Week_Year            28
# dtype: int64

# %%
High_Price_Items
# Out:
#        order_details_id  order_id               pizza_id  quantity order_date  \
# 48592              3448      1528          the_greek_xxl         1 2015-01-26
# 48593              3564      1581          the_greek_xxl         1 2015-01-27
# 48594              5902      2614          the_greek_xxl         1 2015-11-26
# 48595              6366      2813          the_greek_xxl         1 2015-02-16
# 48596              7491      3297          the_greek_xxl         1 2015-02-25
# 48597              9845      4307          the_greek_xxl         1 2015-03-14
# 48598             10283      4498          the_greek_xxl         1 2015-03-17
# 48599             10876      4761          the_greek_xxl         1 2015-03-21
# 48600             13512      5927          the_greek_xxl         1 2015-04-10
# 48601             13780      6038          the_greek_xxl         1 2015-04-12
# 48602             14030      6150          the_greek_xxl         1 2015-04-13
# ...

# %%
High_Price_Items_Data_Categories = High_Price_Items.groupby(['category'], as_index = False)['unit_price'].sum()
High_Price_Items_Data_Categories
# Out:
#   category  unit_price
# 0  Classic      1006.6

# %% [markdown]
# ### we found that all of them are from Classic type.

# %%
High_Price_Items_Data_Categories = High_Price_Items.groupby(['size'], as_index = False)['unit_price'].sum()
High_Price_Items_Data_Categories
# Out:
#   size  unit_price
# 0  XXL      1006.6

# %% [markdown]
# ### we found that all of them are XXL in size that make them high in price

# %% [markdown]
# # we want to fillter all christmas sales:

# %%
December_Sales_Data = merged_data[merged_data['Month_Year']== '2015-12']
December_Sales_Data
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 3720              44786     19680     hawaiian_m         1 2015-12-01
# 3721              44803     19690     hawaiian_m         1 2015-12-01
# 3722              44811     19692  pep_msh_pep_m         1 2015-12-01
# 3723              44818     19695  classic_dlx_m         1 2015-12-01
# 3724              44820     19695    pepperoni_m         1 2015-12-01
# ...                 ...       ...            ...       ...        ...
# 48588             48221     21189   the_greek_xl         1 2015-12-28
# 48589             48373     21243   the_greek_xl         1 2015-12-29
# 48590             48437     21270   the_greek_xl         1 2015-12-30
# 48591             48541     21314   the_greek_xl         1 2015-12-31
# 48619             47490     20866  the_greek_xxl         1 2015-12-20
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
week_Price_Dec_Data = December_Sales_Data.groupby('Week_Year')['total_price'].sum()
week_Price_Dec_Data = week_Price_Dec_Data.reset_index()
week_Price_Dec_Data
# Out:
#                Week_Year  total_price
# 0  2015-11-30/2015-12-06     14390.55
# 1  2015-12-07/2015-12-13     15667.50
# 2  2015-12-14/2015-12-20     15971.00
# 3  2015-12-21/2015-12-27     11427.85
# 4  2015-12-28/2016-01-03      7244.25

# %%
week_Price_Dec_Data['Week_Year'] = week_Price_Dec_Data['Week_Year'].astype(str)

# %%
plt.figure(figsize=(18, 10))
plt.plot(week_Price_Dec_Data['Week_Year'],week_Price_Dec_Data['total_price'], color='red', marker = 'x')
plt.ticklabel_format(useOffset=False, style='plain', axis='y')
plt.title('total Revenue value by week in Dec')
plt.ylabel('Total Amount',fontsize=14)
plt.xlabel('Week', fontsize=14)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
ChristmasSales = week_Price_Dec_Data[(week_Price_Dec_Data['Week_Year'] >= '2015-12-07/2015-12-13') & (week_Price_Dec_Data['Week_Year'] <= '2015-12-21/2015-12-27')]
ChristmasSales
# Out:
#                Week_Year  total_price
# 1  2015-12-07/2015-12-13     15667.50
# 2  2015-12-14/2015-12-20     15971.00
# 3  2015-12-21/2015-12-27     11427.85

# %%
Christmas_Revenue = ChristmasSales['total_price'].sum()
Christmas_Revenue
# Out:
# 43066.35

# %%
Xmas_Percent = (Christmas_Revenue/merged_data['total_price'].sum()) *100
Xmas_Percent
# Out:
# 5.265735867646304

# %% [markdown]
# ### we found the percent form total revenues in year is 5%

# %% [markdown]
# ### get all categories and all types in each one

# %%
pizzaCategory = merged_data.groupby(['category', 'pizza_id'])['pizza_id'].count()
pizzaCategory
# Out:
# category  pizza_id
# Chicken   bbq_ckn_l        967
#           bbq_ckn_m        926
#           bbq_ckn_s        479
#           cali_ckn_l       895
#           cali_ckn_m       914
#                           ...
# Veggie    spinach_fet_m    558
#           spinach_fet_s    437
#           veggie_veg_l     423
#           veggie_veg_m     630
#           veggie_veg_s     457
# Name: pizza_id, Length: 92, dtype: int64

# %%
all_pizza_Names = merged_data['pizza_id'].unique()
all_pizza_Names
# Out:
# array(['hawaiian_m', 'classic_dlx_m', 'ital_cpcllo_m', 'pepperoni_m',
#        'pep_msh_pep_m', 'the_greek_m', 'napolitana_m', 'mexicana_m',
#        'four_cheese_m', 'mediterraneo_m', 'green_garden_m',
#        'veggie_veg_m', 'ital_veggie_m', 'spinach_fet_m', 'spin_pesto_m',
#        'ital_supr_m', 'calabrese_m', 'sicilian_m', 'peppr_salami_m',
#        'spinach_supr_m', 'prsc_argla_m', 'spicy_ital_m', 'soppressata_m',
#        'cali_ckn_m', 'bbq_ckn_m', 'ckn_alfredo_m', 'thai_ckn_m',
#        'ckn_pesto_m', 'southw_ckn_m', 'the_greek_s', 'classic_dlx_s',
#        'big_meat_s', 'napolitana_s', 'pepperoni_s', 'hawaiian_s',
#        'pep_msh_pep_s', 'ital_cpcllo_s', 'green_garden_s', 'mexicana_s',
#        'veggie_veg_s', 'ital_veggie_s', 'spin_pesto_s', 'spinach_fet_s',
#        'mediterraneo_s', 'spinach_supr_s', 'ital_supr_s',
#        'peppr_salami_s', 'prsc_argla_s', 'sicilian_s', 'spicy_ital_s',
#        'brie_carre_s', 'calabrese_s', 'soppressata_s', 'bbq_ckn_s',
# ...

# %%
Low_Price_pizza = merged_data[merged_data['unit_price'] == 9.750000]
Low_Price_pizza
# Out:
#        order_details_id  order_id     pizza_id  quantity order_date  \
# 15393                78        31  pepperoni_s         1 2015-01-01
# 15407               189        80  pepperoni_s         1 2015-01-02
# 15410               214        91  pepperoni_s         1 2015-01-02
# 15416               270       112  pepperoni_s         1 2015-01-02
# 15424               312       132  pepperoni_s         1 2015-01-02
# ...                 ...       ...          ...       ...        ...
# 21330             48369     21242  pepperoni_s         1 2015-12-29
# 21331             48375     21244  pepperoni_s         1 2015-12-29
# 21344             48483     21293  pepperoni_s         1 2015-12-31
# 21348             48520     21304  pepperoni_s         1 2015-12-31
# 21354             48551     21318  pepperoni_s         1 2015-12-31
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
lowest_price_Names = Low_Price_pizza['pizza_id'].unique()
lowest_price_Names
# Out:
# array(['pepperoni_s'], dtype=object)

# %%
lowest_price_Names = Low_Price_pizza['category'].unique()
lowest_price_Names
# Out:
# array(['Classic'], dtype=object)

# %% [markdown]
# ## low price pizza and cheaper one is 'pepperoni_s' from 'Classic' category

# %%
cheapestPizza = merged_data[(merged_data['pizza_id']=='pepperoni_s') & (merged_data['category']=='Classic')]
cheapestPizza
# Out:
#        order_details_id  order_id     pizza_id  quantity order_date  \
# 15393                78        31  pepperoni_s         1 2015-01-01
# 15407               189        80  pepperoni_s         1 2015-01-02
# 15410               214        91  pepperoni_s         1 2015-01-02
# 15416               270       112  pepperoni_s         1 2015-01-02
# 15424               312       132  pepperoni_s         1 2015-01-02
# ...                 ...       ...          ...       ...        ...
# 21330             48369     21242  pepperoni_s         1 2015-12-29
# 21331             48375     21244  pepperoni_s         1 2015-12-29
# 21344             48483     21293  pepperoni_s         1 2015-12-31
# 21348             48520     21304  pepperoni_s         1 2015-12-31
# 21354             48551     21318  pepperoni_s         1 2015-12-31
#
#        order_time  unit_price  total_price  pizza_size_id  pizza_category_id  \
# ...

# %%
Revenues_from_Cheap = cheapestPizza['total_price'].sum()
Revenues_from_Cheap
# Out:
# 7322.25

# %%
Total_Revenues = merged_data['total_price'].sum()
Total_Revenues
# Out:
# 817860.0499999999

# %%
Revenues_from_Cheap_Percent = (Revenues_from_Cheap/Total_Revenues) *100
Revenues_from_Cheap_Percent
# Out:
# 0.8952937608335314

# %% [markdown]
# ## it is very low percent  from total revenues

# %%
plt.figure(figsize=(18, 10))
sns.boxplot(x='category', y='total_price', data= merged_data, palette='Set2')
plt.title('Distribution of sales by category type')
plt.ylabel('Total Price')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Supreme has higher avg than anything else.
# ### chicken has high outliers.
# ### Classic has many outliers

# %%
with pd.ExcelWriter('Pizza_sales_analysis_results.xlsx', engine='xlsxwriter') as writer:
    # Export each DataFrame to a separate sheet
    merged_data.to_excel(writer, sheet_name='All Good Data', index=False)
    category_total.to_excel(writer, sheet_name='category Revenues', index=False)
    Morethan_20_inUnit_price.to_excel(writer, sheet_name='More_than_20_in_Unit_price', index=False)
    size_more_than_20.to_excel(writer, sheet_name='sizes_Rev_more_than_20_UP', index=False)
    quantity_Data_more_than_1.to_excel(writer, sheet_name='Sold_Items_more_than_1', index=False)
    Highest_repeated_quantity.to_excel(writer, sheet_name='Highest_repeated_quantity', index=False)
    month_Price_Data.to_excel(writer, sheet_name='Sales every month', index=False)
    June_Sales_Data.to_excel(writer, sheet_name='Sales in June', index=False)
    week_Price_Data.to_excel(writer, sheet_name='sales in each week in June', index=False)
    June_Sales_Data_Categories.to_excel(writer, sheet_name='Category sales in weeks in June', index=False)
    High_Price_Items.to_excel(writer, sheet_name='Highest_Price Items', index=False)
    High_Price_Items_Data_Categories.to_excel(writer, sheet_name='High Price Items Categories', index=False)
    December_Sales_Data.to_excel(writer, sheet_name='December Sales', index=False)
    week_Price_Dec_Data.to_excel(writer, sheet_name='December weeks sales', index=False)
    ChristmasSales.to_excel(writer, sheet_name='Christmas Sales', index=False)
    pizzaCategory.to_excel(writer, sheet_name='pizza Categories names', index=False)
    Low_Price_pizza.to_excel(writer, sheet_name='Low Price pizza name sales', index=False)
 
print("Analysis exported to 'Pizza_sales_analysis_results.xlsx'")
# Out:
# Analysis exported to 'Pizza_sales_analysis_results.xlsx'
